# %%
import pandas as pd 
import geocoder 
from geopy.geocoders import Nominatim
import requests as req
from bs4 import BeautifulSoup as bs

# %%
df = pd.read_csv('toronto.csv')
df.head()
# Out:
#   Postal Code      Borough                           Neighbourhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %%
# lat_lng_coords = None

# while lat_lng_coords is None :
#   g = geocoder.google('{}, Toronto, Ontario'.format('M1B'))
#   lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# %%
g = geocoder.google('MIB, Toronto, Ontario')
g
# Out:
# <[REQUEST_DENIED] Google - Geocode [empty]>

# %%
def lat_long(code):
    geolocator = Nominatim(user_agent="my_user_agent")
    loc = geolocator.geocode(f'{code}, Toronto, Ontario')
    return loc

# %%
codes = [lat_long(i) for i in df['Postal Code'][:10]]
codes[:10]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# lat = []
# long = []

# for i in codes:
#     lat.append(i.latitude)
#     long.append(i[1].longitude)

# %%
# for code in df['Postal Code'][:10]:
#     geolocator = Nominatim(user_agent="my_user_agent")
#     loc = geolocator.geocode(f'{code}, Toronto, Ontario')
#     print(loc.latitude)

code = 'M1B'

# %%
url = 'https://www.google.com/search?rlz=1C1SQJL_enIN847IN847&sxsrf=ALeKk03ld70k9eQl60dzcG3FXH2kK-C2hA%3A1611636338612&ei=cp4PYMXkJLr7z7sP8MSi2Ag&q={code}+toronto+ontario+latitude+and+longitude&oq={code}+toronto+ontario+latitude+and+longitude&gs_lcp=CgZwc3ktYWIQAzIECCMQJzoHCAAQRxCwA1DhryZYmcQmYO_RJmgBcAJ4AIABeogByQOSAQMwLjSYAQCgAQGqAQdnd3Mtd2l6yAEIwAEB&sclient=psy-ab&ved=0ahUKEwjF5eCb5bjuAhW6_XMBHXCiCIsQ4dUDCA0&uact=5'

# %%
# res = req.get(url.format(code=code))

# %%
session = req.Session()

# %%
session.headers
# Out:
# {'User-Agent': 'python-requests/2.22.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
session.headers['User-Agent'] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36"
session.headers['sec-ch-ua'] = '"Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"'

# %%
res = session.get(url.format(code=code))

# %%
res.content
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="Ah218ykAAxvj9jnTY3BRXS67iOnTb6+IIYKz8ehd8piOyCz0WQN0FGEGG4RhI27/laDS2jxw+PiNBq0vF2PZBwcAAABieyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjEzNTAyOTc4LCJpc1N1YmRvbWFpbiI6dHJ1ZX0=" http-equiv="origin-trial"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>M1B toronto ontario latitude and longitude - Google Search</title><script nonce="IjBh/jnPNZBoj4qQWcPW8A==">(function(){window.google={kEI:\'aKQPYPqhFqbSz7sPhK6X8Ao\',kEXPI:\'31\',kBL:\'CHOb\'};google.sn=\'web\';google.kHL=\'en-IN\';})();(function(){\ngoogle.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.g
# ...

# %%
soup = bs(res.content,'html.parser')

# %%
for i in soup.find_all('div'):
    print(i.text)
# Out:
# Accessibility linksSkip to main contentAccessibility helpAccessibility feedback
# Skip to main contentAccessibility helpAccessibility feedback
# Skip to main contentAccessibility helpAccessibility feedback
# Accessibility feedback
#
#
# Please click here if you are not redirected within a few seconds.
#
#              RemoveReport inappropriate predictions
#
#
#
#
#             RemoveReport inappropriate predictions
#            RemoveReport inappropriate predictions
#
#
#
#
#
#
#
#
#
#
#
# RemoveReport inappropriate predictions
#
# Remove
#
# Remove
#
#
#
#
# Remove
# Remove
# Report inappropriate predictions
#
#
#
#
#
# (function(){var j=1280;
# try{var a=document.getElementById("cnt"),b=document.getElementById("searchform"),c="";if(window.gbar&&gbar.elr){var d=gbar.elr().mo;c="md"==d?" mdm":"lg"==d?" big":""}else{var e=document.body&&document.body.offsetWidth;e&&e>=j&&(c=" big")}a&&(a.className+=c);b&&(b.className+=c)}catch(f){google.ml(f,!1,{elr:!0})};})();(function(){
# ...

# %% [markdown]
# ### In the end geocoder module didnt give the output
